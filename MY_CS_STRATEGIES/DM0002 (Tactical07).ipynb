# %%
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import itable
import ffn

from fintools.Parameters import Parameters
from fintools.set_start_end import set_start_end
from fintools.get_yahoo_prices import get_yahoo_prices
from fintools.compute_weights_RS_DM import compute_weights_RS_DM
from fintools.compute_weights_PMA import compute_weights_PMA
from fintools.endpoints import endpoints
from fintools.backtest import backtest
from fintools.monthly_return_table import monthly_return_table
from fintools.show_return_table import show_return_table
from fintools.finhelpers3 import highlight_pos_neg

# %matplotlib inline
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

strategies = {'DM0002': {'symbols': ['VCVSX', 'VUSTX', 'VWEHX', 'VFIIX',
                                     'VGHCX', 'FRESX'], 'prices': 'yahoo',
                         'start': '1986-01-01', 'end': 'today',
               'rs_lookback': 1, 'risk_lookback': 1, 'n_top': 5, 'frequency': 'M',
               'cash_proxy': 'VFIIX', 'risk_free': 'FFXSX'}}

for name in strategies:
    s_value, s_holdings, s_weights, s_prices = compute_weights_RS_DM(name, strategies[name])

s_value.plot(figsize=(15, 10), grid=True)

ffn.calc_perf_stats(s_value).display()

show_return_table(s_value)
# Out:
# Strategy : DM0002
# FIRST BUY DATE = 1986-12-31 00:00:00
#
# Stats for None from 1986-12-31 00:00:00 - 2018-08-14 00:00:00
# Annual risk-free rate considered: 0.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 2225.07%            1.69  10.46%  -7.91%
#
# Annualized Returns:
# mtd    3m     6m     ytd    1y     3y     5y     10y    incep.
# -----  -----  -----  -----  -----  -----  -----  -----  --------
# 0.33%  3.39%  4.94%  2.65%  3.81%  3.51%  5.32%  8.36%  10.46%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.69     1.78       1.51
# mean    10.13%   10.14%     10.54%
# vol     5.98%    5.69%      6.96%
# skew    0.01     -0.02      0.57
# kurt    10.95    2.02       -0.56
# best    4.98%    8.90%      24.31%
# worst   -3.30%   -5.06%     0.69%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -7.91%  -0.83%     18.26
#
# Misc:
# ---------------  -------
# avg. up month    1.54%
# avg. down month  -1.14%
# up year %        100.00%
# 12m up %         96.76%
# ---------------  -------
# <style  type="text/css" >
#     #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col2 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col3 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col4 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col7 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col8 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col10 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow0_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col2 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col3 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col4 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col6 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col7 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col8 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col10 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow1_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col1 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col2 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col3 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col7 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col8 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col10 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow2_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col0 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col2 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col3 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col7 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col8 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col10 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow3_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col2 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col3 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col5 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col7 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col8 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col10 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow4_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow5_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow5_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow5_col2 {
#             background-color :  rgb(255,99,71);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow5_col3 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow5_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_27587d32_a08c_11e8_9cb8_e8de274bf76frow5_col5 {
#             background-color :  rgb(255,99,71);
#         }    #T_
