# %%
import ffn

from fintools.Parameters import Parameters
from fintools.set_start_end import set_start_end
from fintools.get_yahoo_prices import get_yahoo_prices
from fintools.compute_weights_RS_DM import compute_weights_RS_DM
from fintools.endpoints import endpoints
from fintools.backtest import backtest
from fintools.monthly_return_table import monthly_return_table
from fintools.show_return_table import show_return_table

# %matplotlib inline

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

strategies = {
    'DM0001': {'symbols': ['VCVSX', 'VWINX', 'VWEHX', 'VGHCX', 'VUSTX', 'VFIIX',
                           'VWAHX', 'FGOVX', 'FFXSX'],
               'prices': 'yahoo', 'start': '1986-01-01', 'end': 'today',
               'rs_lookback': 1, 'risk_lookback': 1, 'n_top': 3, 'frequency': 'M',
               'cash_proxy': 'CASHX', 'risk_free': 'FFXSX'}}

for name in strategies:
    s_value, s_holdings, s_weights, s_prices = compute_weights_RS_DM(name, strategies[name])

s_value.plot(figsize=(15, 10), grid=True)

ffn.calc_perf_stats(s_value).display()

show_return_table(s_value)
# Out:
# Strategy : DM0001
# FIRST BUY DATE = 1986-12-31 00:00:00
#
# Stats for None from 1986-12-31 00:00:00 - 2018-08-14 00:00:00
# Annual risk-free rate considered: 0.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 2501.93%            1.79  10.86%  -7.99%
#
# Annualized Returns:
# mtd    3m     6m     ytd     1y      3y     5y     10y    incep.
# -----  -----  -----  ------  ------  -----  -----  -----  --------
# 0.41%  2.91%  2.77%  -1.71%  -0.27%  2.53%  4.90%  8.94%  10.86%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.79     1.81       1.47
# mean    10.48%   10.50%     10.96%
# vol     5.85%    5.81%      7.46%
# skew    -0.21    0.11       0.44
# kurt    3.77     0.04       -0.34
# best    2.26%    6.17%      27.31%
# worst   -3.37%   -3.47%     -1.71%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -7.99%  -0.93%     20.13
#
# Misc:
# ---------------  ------
# avg. up month    1.77%
# avg. down month  -0.93%
# up year %        96.88%
# 12m up %         95.14%
# ---------------  ------
# <style  type="text/css" >
#     #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col2 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col3 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col4 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col7 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col8 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col9 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col10 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow0_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col2 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col3 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col4 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col6 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col7 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col8 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col10 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow1_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col1 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col2 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col3 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col7 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col8 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col10 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow2_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col0 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col1 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col2 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col3 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col5 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col7 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col8 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col10 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow3_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col0 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col2 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col3 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col5 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col6 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col7 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col8 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col9 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col10 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col11 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow4_col12 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow5_col0 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow5_col1 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow5_col2 {
#             background-color :  rgb(255,99,71);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow5_col3 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow5_col4 {
#             background-color :  rgb(127,255,0);
#         }    #T_f9954538_a08b_11e8_9cb8_e8de274bf76frow5_col5 {
#             background-color :  rgb(255,99,71);
#         }    #T_
